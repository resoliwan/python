# %%
import pandas as pd
import numpy as np
from sklearn.cross_validation import train_test_split

# %%
import os
print os.getcwd()
# Out:
# /Users/younlee/PycharmProjects/python/talking

# %%
events = pd.read_csv("./data/events.csv", dtype={"device_id":str})

# %%
events.groupby(['device_id']).agg('count')
# Out:
#                       event_id  timestamp  longitude  latitude
# device_id
# -100015673884079572         50         50         50        50
# -1000458529741848912         1          1          1         1
# -1000667340060427374       203        203        203       203
# -100098646088222553          4          4          4         4
# -100101996136889832         14         14         14        14
# -1001337759327042486       109        109        109       109
# -1001384358977718793         7          7          7         7
# -1001763197518045615       102        102        102       102
# -1002343061859436033       413        413        413       413
# -1002595372059179606         7          7          7         7
# -1002733576670974332        55         55         55        55
# -1002969456091702673         7          7          7         7
# -1003115270132638814       221        221        221       221
# -1003191529145957924         2          2          2         2
# ...

# %%
device_check = events[events['device_id'] == '-100015673884079572']

# %%
device_check.groupby(['device_id', 'event_id']).agg('count')
# Out:
#                               timestamp  longitude  latitude
# device_id           event_id
# -100015673884079572 37147             1          1         1
#                     63868             1          1         1
#                     109309            1          1         1
#                     193485            1          1         1
#                     336968            1          1         1
#                     826291            1          1         1
#                     838661            1          1         1
#                     898870            1          1         1
#                     961020            1          1         1
#                     1004583           1          1         1
#                     1026437           1          1         1
#                     1032393           1          1         1
#                     1077411           1          1         1
#                     1183940           1          1         1
# ...
